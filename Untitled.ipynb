# %%
import pandas as pd
#to print/read the whole data;
df = pd.read_csv('pokemon_data.csv')
#prints the whole data from 0 till the end of file
print(df[0:])
#to print the column in the data
print(df.columns)
#to print top 5 rows
print(df.head())
#to print first row only
print(df.head(1))
#to print single/specific coloumn
print('\nPrinting single colmn')
print(df['Name'])
print('\nprinting multiple desired colmns')
print(df[['Name','Type 1','Attack']])
print('\nfirst row')
print(df.iloc[1])

print('\nRead specific row specific colmn')
print(df.iloc[2,1])
print('\nconditioning')
df.loc[df['Name']=="Bulbasaur"]
#print(df)
#df.sort_values(['Type 1','HP'], ascending=True)
#df['Total'] = df['HP'] + df['Attack'] + df['Defense']
#df.head(5)

#df.to_csv('modified.csv')
#filtering the data
df.loc[(df['Type 1']=='Grass' )&(df['Type 2']=='Poison')]
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
# Out:
# 143

# %%
# Out:
#   File "<ipython-input-27-95cd6c39ca84>", line 2
#     df.loc[(df['Type 1']=='Grass' )&&(df['Type 2']=='Poison')]
#                                     ^
# SyntaxError: invalid syntax
